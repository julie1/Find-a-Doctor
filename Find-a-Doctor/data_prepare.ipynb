# %%
import pandas as pd
data = './Find-a-Doctor/data/hip_surgeons.csv'

# %%
df = pd.read_csv(data, sep=',')

# %%
df
# Out:
#      orthopedic_surgeon_first_name orthopedic_surgeon_surname  \
# 0                          Michael                   Anderson
# 1                             Neil                    Bergman
# 2                            Roger                   Brighton
# 3                         Roderick                     Brooks
# 4                        Rodney E.                    Dalziel
# ...                            ...                        ...
# 1031                    Jeffrey S.                      Zarin
# 1032                       Fady D.                     Zeidan
# 1033                     Steven B.                    Zelicof
# 1034                       Cory D.                     Zieger
# 1035                     Joseph D.                  Zuckerman
#
#                                              jpg_doctor      born_year  \
# 0                                         missing_value  missing_value
# 1                           X (doctors/neilbergman.jpg)  missing_value
# 2                         X (doctors/rogerbrighton.jpg)  missing_value
# 3                        X (doctors/roderickbrooks.jpg)  missing_value
# 4                            X (doctors/roddalziel.jpg)  missing_value
# ...                                                 ...            ...
# 1031                                      missing_value  missing_value
# 1032                                      missing_value  missing_value
# 1033  X (file:///C:\Users\Ron%20van%20Mierlo\AppData...  missing_value
# 1034  X (file:///C:\Users\Ron%20van%20Mierlo\AppData...  missing_value
# 1035  X (file:///C:\Users\Ron%20van%20Mierlo\AppData...  missing_value
#
#                                                 address                street  \
# 0                  Murdoch University Medical\n  Centre     100 Murdoch Drive
# 1                           Warringal Medical\n  Centre   214 Burgundy Street
# 2        Central West Orthopaedics\n  & Sports Injuries    30 Campbell Street
# 3                                         missing_value      2 Redleaf Avenue
# 4                           Melbourne Orthopaedic Group  33 The Avenue Street
# ...                                                 ...                   ...
# 1031                                      missing_value   720 Harrison Avenue
# 1032  Suncoast Orthopaedics\n  & Sports Medicine Center   10441 Quality Drive
# 1033                    Specialty Orthopaedics,\n  PLLC      311 North Street
# 1034                             Bone & Joint Institute  2611 Electric Avenue
# 1035                 NYU Hospital for Joint\n  Diseases  301 East 17th Street
#
#               local          city postal_code    country  ...  \
# 0          Suite 10       Murdoch         W-A  Australia  ...
# 1          Suite 10    Heidelberg    VIC 3084  Australia  ...
# 2         Suite 204     Blacktown    NSW 2148  Australia  ...
# 3     missing_value     Wahroonga    NSW 2076  Australia  ...
# 4           Windsor     Melbourne    VIC 3181  Australia  ...
# ...             ...           ...         ...        ...  ...
# 1031  missing_value        Boston    MA 02118        USA  ...
# 1032      Suite 202   Spring Hill    FL 34609        USA  ...
# 1033      Suite 206  White Plains    NY 10605        USA  ...
# 1034        Suite E    Port Huron    MI 48060        USA  ...
# 1035     Suite 1402      New York    NY 10003        USA  ...
#
#      this_joint_capsule_saved_all cut_muscles_is_fixed_again  \
# 0                   missing_value              missing_value
# 1                   missing_value              missing_value
# 2                   missing_value              missing_value
# 3                   missing_value              missing_value
# 4                   missing_value              missing_value
# ...                           ...                        ...
# 1031                missing_value              missing_value
# 1032                missing_value              missing_value
# 1033                missing_value              missing_value
# 1034                missing_value              missing_value
# 1035                missing_value              missing_value
#
#      complete_opera_report_is_given hr_average_size hr_average_location  \
# 0                     missing_value   missing_value       missing_value
# 1                     missing_value   missing_value       missing_value
# 2                     missing_value   missing_value       missing_value
# 3                     missing_value   missing_value       missing_value
# 4                     missing_value   missing_value       missing_value
# ...                             ...             ...                 ...
# 1031                  missing_value   missing_value       missing_value
# 1032                  missing_value   missing_value       missing_value
# 1033                  missing_value   missing_value       missing_value
# 1034                  missing_value   missing_value       missing_value
# 1035                  missing_value   missing_value       missing_value
#
#      assesses_x-ray x-ray_at_discharge two-sided_operation foreign_patients  \
# 0     missing_value      missing_value       missing_value    missing_value
# 1     missing_value      missing_value       missing_value    missing_value
# 2     missing_value      missing_value       missing_value    missing_value
# 3     missing_value      missing_value       missing_value    missing_value
# 4     missing_value      missing_value       missing_value    missing_value
# ...             ...                ...                 ...              ...
# 1031  missing_value      missing_value       missing_value    missing_value
# 1032  missing_value      missing_value       missing_value    missing_value
# 1033  missing_value      missing_value       missing_value    missing_value
# 1034  missing_value      missing_value       missing_value    missing_value
# 1035  missing_value      missing_value       missing_value    missing_value
#
#      patient-reported_complications
# 0                     missing_value
# 1                     missing_value
# 2                     missing_value
# 3                     missing_value
# 4                     missing_value
# ...                             ...
# 1031                  missing_value
# 1032                  missing_value
# 1033                  missing_value
# 1034                  missing_value
# 1035                  missing_value
#
# [1036 rows x 35 columns]

# %%
# pandas settings are local to with statement.
with pd.option_context('display.max_rows', None,
                       'display.max_columns', None,
                       'display.precision', 3,
                       ):
    print(df['orthopedic_surgeon_surname'])
# Out:
# 0                Anderson
# 1                 Bergman
# 2                Brighton
# 3                  Brooks
# 4                 Dalziel
# 5                   Dunin
# 6                    Fick
# 7                   Kohan
# 8                     Lee
# 9                    Love
# 10               Mc Mahon
# 11                 Morgan
# 12              Oakeshott
# 13                  Robin
# 14                Shimmin
# 15                  Smith
# 16                Solomon
# 17              Stackpool
# 18                 Waller
# 19                 Walter
# 20               Woodgate
# 21                  Yates
# 22                  Young
# 23               De Gendt
# 24                De Smet
# 25                Delport
# 26               Goossens
# 27              Jansegers
# 28                  Kloos
# 29                Mertens
# 30                Mortelé
# 31                   Lage
# 32                  Rocha
# 33               Antoniou
# 34                 Beaulé
# 35                Burnett
# 36                  Clark
# 37                 deBeer
# 38                 Feibel
# 39                 Garbuz
# 40              Greidanus
# 41      Huk-Papanastasiou
# 42                Kendall
# 43                    Kim
# 44                Lavigne
# 45              Lichtblau
# 46              MacKenzie
# 47                  Masri
# 48          Mastrogiacomo
# 49            Mc Allister
# 50                 Powell
# 51                    Roy
# 52             Schemitsch
# 53                   Smit
# 54                  Smith
# 55               Thurston
# 56            van Sittert
# 57             Vendittoli
# 58                  Werle
# 59              Winemaker
# 60                   Wood
# 61                Halonen
# 62                 Kassis
# 63                   Berg
# 64                  Beyer
# 65                 Braick
# 66             Breithaupt
# 67               Diedrich
# 68                   Doss
# 69               Eckhardt
# 70              Engelmann
# 71                  Eysel
# 72                Faensen
# 73                  Frank
# 74            Gerdesmeyer
# 75                 Glaser
# 76              Gradinger
# 77                Günther
# 78                Heimann
# 79                 Hertel
# 80                   Hess
# 81                  Hille
# 82               Hoffmann
# 83                Jerosch
# 84           Kerschbaumer
# 85                  Klein
# 86               Kokoszka
# 87                  Kujat
# 88                 Köhler
# 89                Lawrenz
# 90                Lindner
# 91                 Lütten
# 92                Machner
# 93                Meister
# 94                  Menge
# 95               Menslage
# 96                  Meyer
# 97                 Morick
# 98                 Müller
# 99                Neitzel
# 100               Nerlich
# 101           Rahmanzadeh
# 102              Reichert
# 103                 Reize
# 104               Roesgen
# 105            Rossmeissl
# 106               Rümelin
# 107                 Sarem
# 108             Schietsch
# 109               Schmidt
# 110                Scholz
# 111               Schunck
# 112             Schürmann
# 113               Seifert
# 114                Siebel
# 115                 Simon
# 116              Sprenger
# 117             Stedtfeld
# 118                 Stoll
# 119              Suntheim
# 120                 Szöke
# 121               Thomsen
# 122              Tsolakis
# 123                Waibel
# 124              van Ende
# 125                Winter
# 126                Völker
# 127             Zurstegge
# 128           Zwingenberg
# 129             Brockwell
# 130                Hooley
# 131              Agarwala
# 132       Balasubramanian
# 133                  Bose
# 134          Chakravarthy
# 135                Malhan
# 136               Manjure
# 137                 Marya
# 138                 Mukhi
# 139               Pispati
# 140                Ranjit
# 141               Thakkar
# 142                Thilak
# 143        Thirumalaisamy
# 144         Venkatachalam
# 145                  Kaar
# 146             Nicholson
# 147            O’Sullivan
# 148                 Levin
# 149                Velkes
# 150                Ishibe
# 151         missing_value
# 152                     ?
# 153                     ?
# 154                     ?
# 155                     ?
# 156                     ?
# 157                     ?
# 158                     ?
# 159                     ?
# 160                     ?
# 161                     ?
# 162                Bimmel
# 163                   Bom
# 164              Breemans
# 165                Dartée
# 166       de Meulemeester
# 167      de Waal Malefijt
# 168              Hoekstra
# 169                Jansen
# 170                Keizer
# 171               Lacroix
# 172                 Lampe
# 173            Middendorf
# 174              Pittoors
# 175               Schepel
# 176                 Speth
# 177              ten Kate
# 178         van der Flier
# 179          van der Hart
# 180             van Empel
# 181               van Erp
# 182                  Veen
# 183               Verhaar
# 184             Westerink
# 185                 Zwart
# 186              Blackley
# 187            Farrington
# 188                 Pitto
# 189              Bierling
# 190                Borgen
# 191             Jervidalo
# 192                 Röhrl
# 193             Snorrason
# 194             Laskowski
# 195                  Meek
# 196                    De
# 197                  Wang
# 198               Erasmus
# 199         van Huyssteen
# 200               Stewart
# 201              Williams
# 202              Breemans
# 203                 Digas
# 204                Flivik
# 205               Granath
# 206               Gremark
# 207               Havdrup
# 208               Hedlund
# 209              Hedlundh
# 210               Hyldahl
# 211                Itayem
# 212              Kesteris
# 213              Kärrholm
# 214                Linvik
# 215              Lundberg
# 216              Milbrink
# 217                Nistor
# 218                Nyberg
# 219              Olofsson
# 220              Skytting
# 221              Sundberg
# 222              Sundgren
# 223           Weidenhielm
# 224           Wilhelmsson
# 225            Wretenberg
# 226         missing_value
# 227                Åström
# 228              Arlettaz
# 229            Gambirasio
# 230               Hersche
# 231              Holzmann
# 232                   Hug
# 233               Leyvraz
# 234                  Naal
# 235                Orapin
# 236               Whately
# 237                 Ahmed
# 238                 Aldam
# 239                   Ali
# 240                 Allen
# 241                   Alo
# 242              Anderson
# 243               Apthorp
# 244              Ashcroft
# 245                 Aweid
# 246             Bannister
# 247                Barnes
# 248            Birtwistle
# 249            Bloomfield
# 250              Campbell
# 251            Carrington
# 252                 Chana
# 253              Charnley
# 254              Chissell
# 255                 Chugh
# 256                 Clark
# 257                  Cobb
# 258                  Cobb
# 259                D'Arcy
# 260             Donnachie
# 261                 Drabu
# 262                Dunlop
# 263              Fairbank
# 264                  Fern
# 265                 Field
# 266               Fordyce
# 267             Ganapathi
# 268              Grigoris
# 269                Gundle
# 270                Haddad
# 271               Holland
# 272               Housden
# 273                  Hull
# 274               Ibister
# 275                 James
# 276              Johnsson
# 277             Journeaux
# 278              Kavanagh
# 279               Krikler
# 280              Langston
# 281                Latham
# 282                   Lin
# 283             Majkowski
# 284             Manktelow
# 285              Markovic
# 286                 Marsh
# 287             McAuliffe
# 288               Mc Minn
# 289                  Meek
# 290             Middleton
# 291                 Moore
# 292                Morell
# 293      Muirhead-Allwood
# 294                Nargol
# 295                O'Hara
# 296              Pearsson
# 297                Porter
# 298               Prakash
# 299            Richardson
# 300                Rosson
# 301                Singer
# 302               Skinner
# 303               Sochart
# 304                 Stock
# 305                Thomas
# 306                Treacy
# 307                Villar
# 308               Woodnut
# 309                  Zahn
# 310                Abdeen
# 311               Abraham
# 312               Achecar
# 313                 Adams
# 314                 Adler
# 315                 Agnew
# 316                   Ahn
# 317             Alexander
# 318             Alexander
# 319                 Allan
# 320              Almacari
# 321               Amstutz
# 322              Anderson
# 323              Anderson
# 324                Andreo
# 325                Anseth
# 326                Antebi
# 327            Antoniades
# 328                 Anwar
# 329              Aparicio
# 330              Aribindi
# 331                Askins
# 332                 Atkin
# 333                 Autry
# 334              Avallone
# 335              Axtmayer
# 336                 Ayres
# 337                 Backe
# 338                 Baker
# 339                 Baker
# 340                Balint
# 341                  Ball
# 342               Balsamo
# 343                 Barba
# 344                Barber
# 345               Bargren
# 346               Barnett
# 347                 Baron
# 348               Barrack
# 349               Barrett
# 350            Barrington
# 351               Barsoum
# 352           Bartholomew
# 353                 Bates
# 354                Becker
# 355                 Behan
# 356                Bender
# 357               Bentley
# 358                Berend
# 359            Berkenblit
# 360               Bernabe
# 361               Bezwada
# 362                Bhagia
# 363                Bhalla
# 364                Bharam
# 365              Birdwell
# 366                Biviji
# 367                 Blaha
# 368               Blevins
# 369                 Bliss
# 370                 Block
# 371                  Blom
# 372              Boettner
# 373               Bolanos
# 374             Bolhofner
# 375                  Bong
# 376                 Boone
# 377                 Borja
# 378            Borowiecki
# 379                Bortel
# 380               Boucher
# 381               Bowling
# 382                 Boyce
# 383                  Boyd
# 384               Bradley
# 385                Brandt
# 386            Branovacki
# 387                Briggs
# 388            Brockmeyer
# 389               Bronson
# 390                Brooks
# 391                Brooks
# 392                 Brown
# 393             Buchalter
# 394                Bugbee
# 395                 Burke
# 396                 Burke
# 397               Burnett
# 398                Burton
# 399               Buscemi
# 400                Butler
# 401             Calendine
# 402             Callander
# 403               Cannova
# 404             Carpenter
# 405                Carter
# 406                Carter
# 407              Carvajal
# 408                 Cecil
# 409              Champine
# 410                  Chan
# 411              Chandran
# 412                  Chao
# 413               Chhabra
# 414                Chiang
# 415                  Chow
# 416              Christie
# 417               Cicoria
# 418                 Clark
# 419                Clarke
# 420               Clyburn
# 421               Cochran
# 422               Colizza
# 423              Comadoll
# 424               Comfort
# 425            Companioni
# 426             Congiusta
# 427                Conlan
# 428               Connors
# 429                  Cook
# 430                  Cook
# 431                Cooney
# 432             Cooperman
# 433                Corces
# 434            Gorczynski
# 435              Courtney
# 436                   Cox
# 437              Crofford
# 438              Cromwell
# 439               Cuellar
# 440                Czajka
# 441             Dabuzhsky
# 442                 Daley
# 443               Dangles
# 444                Davies
# 445                 Davis
# 446                Dayton
# 447               de Bari
# 448               De Boer
# 449           Della Valle
# 450                Demers
# 451                Denzin
# 452               Deveney
# 453               Diamond
# 454              DiCaprio
# 455             Di Cesare
# 456              Diekmann
# 457               DiFazio
# 458                Diment
# 459               Distler
# 460                 Doane
# 461                Dobner
# 462                  Domb
# 463                Downer
# 464            Drinkwater
# 465               Drucker
# 466                  Duda
# 467                 Duhon
# 468                 Dungy
# 469               Dyeball
# 470                Dzenis
# 471                 Earll
# 472                 Ebert
# 473           Ebrahimpour
# 474               Edwards
# 475               Edwards
# 476                  Egan
# 477                Eierle
# 478                 Ellis
# 479                 Ellis
# 480                Elzaim
# 481               Emerson
# 482                  Engh
# 483                  Enis
# 484                 Erens
# 485               Etienne
# 486               Evanich
# 487                  Fait
# 488                 Faust
# 489               Feldman
# 490              Ferguson
# 491              Ferrante
# 492                 Ferro
# 493               Fiewell
# 494                 Finch
# 495                Fisher
# 496               Fischer
# 497              Fletcher
# 498             Flynn Jr.
# 499                Foglar
# 500                Foster
# 501                Fowble
# 502                 Fried
# 503             Friedland
# 504              Gajewski
# 505               Gargaro
# 506                Garver
# 507               Gassner
# 508                 Geist
# 509                Geller
# 510                 Gemas
# 511                Gerber
# 512                Ghazal
# 513              Giordani
# 514               Gilbert
# 515                  Gill
# 516               Glaeser
# 517               Gleason
# 518                 Glenn
# 519               Glosser
# 520                 Gluek
# 521                Goethe
# 522                  Gold
# 523              Goldberg
# 524             Goldsmith
# 525             Goldstein
# 526                 Gorab
# 527            Gorczynski
# 528                Gordon
# 529                Gordon
# 530                Gordon
# 531          Grady-Benson
# 532                Graham
# 533               Grandic
# 534              Graybill
# 535               Grecula
# 536               Greenky
# 537               Greenky
# 538                Greene
# 539                 Gross
# 540                 Gross
# 541               Gunther
# 542                 Gupta
# 543              Gutowski
# 544                 Güzel
# 545           Haidukewych
# 546             Hajaliloo
# 547                  Hajj
# 548                  Hall
# 549              Hallmann
# 550             Hallstrom
# 551              Halstead
# 552                Hanmer
# 553               Hansell
# 554                Hansen
# 555              Hartford
# 556               Harwood
# 557                 Havel
# 558                 Hayek
# 559                 Hecht
# 560                Heiner
# 561                Heiser
# 562              Heithoff
# 563              Helgager
# 564                 Helmy
# 565                Heming
# 566             Henderson
# 567             Henderson
# 568              Hennessy
# 569                Hepner
# 570               Hickman
# 571                 Hicks
# 572      Higginbotham III
# 573                  Hill
# 574                Hilton
# 575                Hirsch
# 576               Hodrick
# 577               Hoffman
# 578                 Holub
# 579                 Homan
# 580              Homesley
# 581               Hopkins
# 582                Horner
# 583              Hotchner
# 584               Housman
# 585                  Howe
# 586                Hozack
# 587                Hribar
# 588                 Huang
# 589                Hubers
# 590                Hubley
# 591            Huddleston
# 592            Huddleston
# 593                  Huff
# 594                  Hung
# 595            Hungerford
# 596                   Huo
# 597                   Hur
# 598                Illgen
# 599               Infante
# 600             Jablonsky
# 601               Jackson
# 602                Jacobs
# 603                 Jaffe
# 604                Jamali
# 605            Jankiewicz
# 606               Jaquith
# 607               Jarrett
# 608              Jennings
# 609                 Jerry
# 610                Jibodh
# 611                Jinnah
# 612               Johnson
# 613               Johnson
# 614             Johnstone
# 615              Kagan II
# 616             Kalayjian
# 617                  Kane
# 618                 Karns
# 619                  Katz
# 620                Kazdan
# 621              Kazewych
# 622                 Keggi
# 623                 Keggi
# 624                Kelley
# 625                 Kelly
# 626               Kennedy
# 627                Kennen
# 628                Kennon
# 629                Kepley
# 630               Kessler
# 631              Ketterer
# 632               Khanuja
# 633                   Kim
# 634                   Kim
# 635                   Kim
# 636               Kimball
# 637                  King
# 638          Kirschenbaum
# 639              Kitziger
# 640               Klapper
# 641                 Klein
# 642             Kleinhenz
# 643                  Klug
# 644                Knight
# 645                Knothe
# 646               Knowlan
# 647                 Kohen
# 648              Kolletis
# 649            Komninakas
# 650                Kopich
# 651                 Kress
# 652               Kreuzer
# 653                Kudrna
# 654                Kuesis
# 655                 Kunec
# 656                Kusuma
# 657            Kwartowitz
# 658                 Lambe
# 659               Lammens
# 660                LaMont
# 661                Landon
# 662                  Lang
# 663                Lannin
# 664                Larson
# 665                Larson
# 666              Lawrence
# 667             Lazzarini
# 668                Leland
# 669                Lennen
# 670                Lennon
# 671             Levengood
# 672                Levine
# 673                Levine
# 674                   Lew
# 675           Lewandowski
# 676                Lieber
# 677                 Light
# 678                 Lilly
# 679               Limbird
# 680              Lindholm
# 681              Liporace
# 682                 Litke
# 683              Lombardi
# 684              Lombardi
# 685             Loniewski
# 686                 Lopez
# 687                 Lorei
# 688                 Louie
# 689             Lowenberg
# 690               Lunseth
# 691                   Luu
# 692                  Lyon
# 693                 Lyons
# 694                Mabrey
# 695              Macaulay
# 696              Maddalon
# 697                Magnus
# 698               Maguire
# 699               Mahoney
# 700                   Mai
# 701                 Maier
# 702                Maitra
# 703               Malchau
# 704                 Malin
# 705              Malinick
# 706                Manner
# 707               Manning
# 708             Marandola
# 709               Marangi
# 710              Marchand
# 711            Mariorenzi
# 712                  Mark
# 713                Markel
# 714                Martin
# 715                Martin
# 716                Marwin
# 717                Masini
# 718                 Mason
# 719               Masonis
# 720               Mathews
# 721               Mathews
# 722                Mathis
# 723                Mathis
# 724                 Matta
# 725              Matthews
# 726                 Matza
# 727                Mayman
# 728                  Mayo
# 729           Mc Allister
# 730             Mc Carthy
# 731            Mc Kissick
# 732              Mc Clure
# 733                Mc Coy
# 734            Mc Culloch
# 735               Mc Gann
# 736              Mc Grath
# 737             Mc Guigan
# 738                Mc Kay
# 739            Mc Kissick
# 740            Mc Manaman
# 741             Mc Master
# 742            Mc Pherron
# 743                Meehan
# 744                 Meere
# 745               Meisles
# 746             Melaragno
# 747               Meldrum
# 748              Melendez
# 749             Mendelson
# 750             Mendelson
# 751             Mendelson
# 752                Mendez
# 753              Menendez
# 754                Mensch
# 755                Merkel
# 756                Merkow
# 757                 Mesko
# 758                 Meyer
# 759             Michalski
# 760             Mikaelian
# 761                Miller
# 762                Miller
# 763                Miller
# 764                Miller
# 765               Minotti
# 766                Mirsky
# 767                Mishra
# 768              Mitchell
# 769            Mitzelfelt
# 770                   Moe
# 771                Mohler
# 772                  Mont
# 773      Montijo (senior)
# 774                 Moore
# 775                Morgan
# 776                  Mori
# 777              Morrison
# 778            Moutsatson
# 779                Muench
# 780                  Muir
# 781                Muller
# 782                Murphy
# 783             Myerthall
# 784            Nagarkatti
# 785                Naidoo
# 786            Nallamothu
# 787                 Nasar
# 788                Nasser
# 789                Nayfeh
# 790         Nelsen-Freund
# 791                Nelson
# 792                Nelson
# 793                Nguyen
# 794                Nunley
# 795                 Oakes
# 796              O'Connor
# 797                    Oh
# 798               O'Keefe
# 799                  Okun
# 800                Olenyn
# 801                 Olson
# 802                 Omari
# 803               O'Meara
# 804               O'Neill
# 805             Oppenheim
# 806               Oskouei
# 807                Ozolin
# 808               Padgett
# 809                Palmer
# 810                Palmer
# 811                 Panek
# 812                Parker
# 813                 Patel
# 814                  Paul
# 815               Peatman
# 816                Pelker
# 817              Pellicci
# 818             Penenberg
# 819                 Petty
# 820             Philippon
# 821              Phillips
# 822               Pittman
# 823              Pizzurro
# 824                 Pocze
# 825              Polakoff
# 826             Polifroni
# 827                 Poole
# 828                Postma
# 829                Powell
# 830                Powell
# 831              Pressman
# 832                 Price
# 833             Pritchett
# 834                  Pugh
# 835                Pullen
# 836                  Puri
# 837               Quesada
# 838               Ranawat
# 839               Randall
# 840                   Rao
# 841             Ratcliffe
# 842              Raterman
# 843               Rathjen
# 844                   Ray
# 845                 Ready
# 846               Reardon
# 847                Rector
# 848               Redondo
# 849                Reeves
# 850                  Reff
# 851                Reilly
# 852                 Reiss
# 853               Reitman
# 854               Richman
# 855               Riegler
# 856                  Ries
# 857                 Rifai
# 858               Roberts
# 859               Roberts
# 860           Robinson II
# 861                 Rodin
# 862              Rodricks
# 863               Rodrigo
# 864             Rodriguez
# 865             Rodriguez
# 866              Rogerson
# 867             Romanelli
# 868               Rosabal
# 869                 Rosen
# 870                 Rosen
# 871                  Ross
# 872                  Roye
# 873                 Rubin
# 874                Rubins
# 875            Rubinstein
# 876               Russell
# 877             Russinoff
# 878                  Ryan
# 879                 Saadi
# 880                Saluja
# 881               Sanders
# 882                Saslow
# 883              Schaefer
# 884             Schiffman
# 885              Schinsky
# 886           Schmalzried
# 887               Schmidt
# 888               Schmitt
# 889             Schneider
# 890             Schneider
# 891               Schreck
# 892              Schubert
# 893               Schultz
# 894               Schultz
# 895               Schultz
# 896               Schultz
# 897              Schutzer
# 898              Schwartz
# 899             Scobercea
# 900                 Scott
# 901                 Scott
# 902              Seaquist
# 903             Sellinger
# 904               Serocki
# 905                Sewell
# 906               Seymour
# 907                  Shah
# 908             Shanfield
# 909               Shapiro
# 910               Sharkey
# 911                Sharma
# 912               Sheehan
# 913              Sheinkop
# 914              Shekhman
# 915               Sheldon
# 916                 Shell
# 917               Sherfey
# 918                 Sheth
# 919                Shinar
# 920               Shrader
# 921                Shrock
# 922             Silverton
# 923             Simenstad
# 924               Simmons
# 925               Simpson
# 926             Sirounian
# 927               Skinner
# 928                Sladek
# 929                Slover
# 930                Smires
# 931                 Smith
# 932                 Smith
# 933                 Smith
# 934                 Smith
# 935               Smucker
# 936                Snider
# 937                Snyder
# 938                Sobeck
# 939                Sparks
# 940              Sparling
# 941                Specht
# 942                Sporer
# 943              Springer
# 944                Squire
# 945              Stachniw
# 946                Stamos
# 947                  Star
# 948                 Stein
# 949             Steinfeld
# 950              Stelmach
# 951              Stephany
# 952            Stephenson
# 953               Stewart
# 954               Stewart
# 955                Stocks
# 956             Stolarski
# 957              Stroemer
# 958                Stubbs
# 959               Stuchin
# 960              Stulberg
# 961                    Su
# 962               Suprock
# 963               Surdyka
# 964                 Swank
# 965               Swanson
# 966                Sydney
# 967                   Tai
# 968                 Talmo
# 969              Tapadiya
# 970                 Teeny
# 971                Telfer
# 972             Terefenko
# 973                Thomas
# 974                Thomas
# 975               Thometz
# 976              Thompson
# 977              Thompson
# 978              Thorsett
# 979                Tilzey
# 980                 Tomek
# 981               Toulson
# 982             Trousdale
# 983                Tuttle
# 984                 Umlas
# 985                 Unger
# 986                   Ure
# 987                  Vail
# 988               Valadie
# 989              Valdivia
# 990          van Dommelen
# 991          Van Flandren
# 992                 Vella
# 993                Verner
# 994           Villafuerte
# 995                 Viola
# 996                 Volpe
# 997              Vorlicky
# 998                Vrabec
# 999                Wagner
# 1000              Waldman
# 1001           Walkiewicz
# 1002             Wallskog
# 1003                Walsh
# 1004               Walter
# 1005                 Ward
# 1006                 Ward
# 1007            Wartinbee
# 1008               Watson
# 1009               Weeden
# 1010            Weisstein
# 1011             Wellborn
# 1012              Welborn
# 1013                Wertz
# 1014              Whatley
# 1015             Wiersema
# 1016             Williams
# 1017                Wills
# 1018                 Wind
# 1019              Wolanin
# 1020                 Wood
# 1021                 Wood
# 1022                Wolff
# 1023              Workman
# 1024               Wright
# 1025                   Wu
# 1026                  Yap
# 1027                   Yi
# 1028                 Youm
# 1029                  Yun
# 1030             Zambrano
# 1031                Zarin
# 1032               Zeidan
# 1033              Zelicof
# 1034               Zieger
# 1035            Zuckerman
# Name: orthopedic_surgeon_surname, dtype: object

# %%
columns = ['orthopedic_surgeon_first_name', 'orthopedic_surgeon_surname', 'jpg_doctor', 'born_year', 'address', 'street', 'local', 'city', 'postal_code', 'country', 'phone_normal', 'phone_free_of_charge', 'fax', 'mobile', 'email', 'homepage', 'number_hr', 'adjusted', 'number_thr', 'number_bmhr', 'type_of_hr_prosthesis', 'type_of_thr_prosthesis', 'operational_technique', 'anesthetic', 'cement_femur_side', 'this_joint_capsule_saved_all', 'cut_muscles_is_fixed_again', 'complete_opera_report_is_given', 'hr_average_size', 'hr_average_location', 'assesses_x-ray', 'x-ray_at_discharge', 'two-sided_operation', 'foreign_patients', 'patient-reported_complications']
values = []
values.append(['Michael', 'Crovetti Jr.', 'NaN', 'NaN', 'Crovetti Orthopaedics and Sports Medicine', '2779 West Horizon Ridge Pkwy', 'Suite #200', 'Henderson', 'NV 89052', 'USA', '(702) 990-2290', 'NaN', 'NaN', 'NaN', 'NaN', 'http://www.crovettiortho.com/Crovetti.html'] + ['NaN']*19)
values.append(['John A.', 'Evans', 'NaN', 'NaN', 'NaN', '414 Navarro Street', 'Suite 1128', 'San Antonio', 'TX 78205', 'USA', '(210) 351-6500', 'NaN', '(210) 351-6509', 'NaN', 'NaN', 'http://orthoevans.com/', '200+'] + ['NaN']*18)
values.append(['M. Christine', 'Young', 'NaN', 'NaN', 'Fracture Clinic', '4040 Finch Avenue East', 'Suite 205', 'Scarborough', 'Ontarion MIS 4V5', '(416) 754-7312' , 'NaN', '(416) 754-0116', '(416) 495-2557', 'mcyoung@bellnet.ca', 'NaN', '200+'] +['NaN']*18)
values.append(['Myung Chul', 'Yoo', 'NaN', 'NaN', 'Dept. of Orthopedic Surgery Kyung Hee University Hospital at Gang-dong', 'Sangil-dong, Gangdong-gu', '#149', 'Seoul 134-727', 'Korea', '+82-2-440-7704, 9', 'NaN', 'NaN', 'NaN', 'mcyookuh@chol.com', 'http://www.kuims.or.kr/index.html', '1000+', 'NaN', 'NaN', 'NaN', 'ConservePlus'] + ['NaN']*14)
values.append(['Andrew', 'Pearson', 'NaN', 'NaN', 'Birmingham Hip Clinic BMI Priory Hospital', 'Priory Road', 'NaN', 'Edgbaston', 'Birmingham B5 7UG', 'United Kingdom', '05600496630', 'NaN', 'NaN', 'NaN', 'info@birmingham-hip-clinic.com', 'http://www.birmingham-hip-clinic.com/', '800+'] + ['NaN']*18)
values.append (['John', 'Skinner', 'NaN', 'NaN', 'Royal National Orthopaedic Hospital', 'Brockley Hill', 'NaN', 'Stanmore' , 'Middlesex HA7 4LP', 'United Kingdom', '020 8954 2300', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', '500+'] + ['NaN']*18)
for val in values: 
    d = dict(zip(columns, val))
    df.loc[len(df)] = d
df = df.replace('NaN', 'missing_value')

# %%
#print(df[df['orthopedic_surgeon_surname'].str.contains(r'[?]')])
import numpy as np
df = df.drop_duplicates()
#df = df.replace(np.nan, None)

df['orthopedic_surgeon_surname'] = df['orthopedic_surgeon_surname'].str.replace('Mc ', 'Mc')
df['orthopedic_surgeon_first_name'] = df['orthopedic_surgeon_first_name'].str.replace(',', '')

df['orthopedic_surgeon_first_name'] = df['orthopedic_surgeon_first_name'].where(df['orthopedic_surgeon_surname'] != 'Masonis', 'John L.')
df = df.fillna('missing_value')
df.drop(df[df['orthopedic_surgeon_surname'].str.contains(r'[?]')].index, inplace=True)
for index, row in df.iterrows():
    
    print (row['orthopedic_surgeon_surname'])
# Out:
# Anderson
# Bergman
# Brighton
# Brooks
# Dalziel
# Dunin
# Fick
# Kohan
# Lee
# Love
# McMahon
# Morgan
# Oakeshott
# Robin
# Shimmin
# Smith
# Solomon
# Stackpool
# Waller
# Walter
# Woodgate
# Yates
# Young
# De Gendt
# De Smet
# Delport
# Goossens
# Jansegers
# Kloos
# Mertens
# Mortelé
# Lage
# Rocha
# Antoniou
# Beaulé
# Burnett
# Clark
# deBeer
# Feibel
# Garbuz
# Greidanus
# Huk-Papanastasiou
# Kendall
# Kim
# Lavigne
# Lichtblau
# MacKenzie
# Masri
# Mastrogiacomo
# McAllister
# Powell
# Roy
# Schemitsch
# Smit
# Smith
# Thurston
# van Sittert
# Vendittoli
# Werle
# Winemaker
# Wood
# Halonen
# Kassis
# Berg
# Beyer
# Braick
# Breithaupt
# Diedrich
# Doss
# Eckhardt
# Engelmann
# Eysel
# Faensen
# Frank
# Gerdesmeyer
# Glaser
# Gradinger
# Günther
# Heimann
# Hertel
# Hess
# Hille
# Hoffmann
# Jerosch
# Kerschbaumer
# Klein
# Kokoszka
# Kujat
# Köhler
# Lawrenz
# Lindner
# Lütten
# Machner
# Meister
# Menge
# Menslage
# Meyer
# Morick
# Müller
# Neitzel
# Nerlich
# Rahmanzadeh
# Reichert
# Reize
# Roesgen
# Rossmeissl
# Rümelin
# Sarem
# Schietsch
# Schmidt
# Scholz
# Schunck
# Schürmann
# Seifert
# Siebel
# Simon
# Sprenger
# Stedtfeld
# Stoll
# Suntheim
# Szöke
# Thomsen
# Tsolakis
# Waibel
# van Ende
# Winter
# Völker
# Zurstegge
# Zwingenberg
# Brockwell
# Hooley
# Agarwala
# Balasubramanian
# Bose
# Chakravarthy
# Malhan
# Manjure
# Marya
# Mukhi
# Pispati
# Ranjit
# Thakkar
# Thilak
# Thirumalaisamy
# Venkatachalam
# Kaar
# Nicholson
# O’Sullivan
# Levin
# Velkes
# Ishibe
# missing_value
# Bimmel
# Bom
# Breemans
# Dartée
# de Meulemeester
# de Waal Malefijt
# Hoekstra
# Jansen
# Keizer
# Lacroix
# Lampe
# Middendorf
# Pittoors
# Schepel
# Speth
# ten Kate
# van der Flier
# van der Hart
# van Empel
# van Erp
# Veen
# Verhaar
# Westerink
# Zwart
# Blackley
# Farrington
# Pitto
# Bierling
# Borgen
# Jervidalo
# Röhrl
# Snorrason
# Laskowski
# Meek
# De
# Wang
# Erasmus
# van Huyssteen
# Stewart
# Williams
# Breemans
# Digas
# Flivik
# Granath
# Gremark
# Havdrup
# Hedlund
# Hedlundh
# Hyldahl
# Itayem
# Kesteris
# Kärrholm
# Linvik
# Lundberg
# Milbrink
# Nistor
# Nyberg
# Olofsson
# Skytting
# Sundberg
# Sundgren
# Weidenhielm
# Wilhelmsson
# Wretenberg
# missing_value
# Åström
# Arlettaz
# Gambirasio
# Hersche
# Holzmann
# Hug
# Leyvraz
# Naal
# Orapin
# Whately
# Ahmed
# Aldam
# Ali
# Allen
# Alo
# Anderson
# Apthorp
# Ashcroft
# Aweid
# Bannister
# Barnes
# Birtwistle
# Bloomfield
# Campbell
# Carrington
# Chana
# Charnley
# Chissell
# Chugh
# Clark
# Cobb
# Cobb
# D'Arcy
# Donnachie
# Drabu
# Dunlop
# Fairbank
# Fern
# Field
# Fordyce
# Ganapathi
# Grigoris
# Gundle
# Haddad
# Holland
# Housden
# Hull
# Ibister
# James
# Johnsson
# Journeaux
# Kavanagh
# Krikler
# Langston
# Latham
# Lin
# Majkowski
# Manktelow
# Markovic
# Marsh
# McAuliffe
# McMinn
# Meek
# Middleton
# Moore
# Morell
# Muirhead-Allwood
# Nargol
# O'Hara
# Pearsson
# Porter
# Prakash
# Richardson
# Rosson
# Singer
# Skinner
# Sochart
# Stock
# Thomas
# Treacy
# Villar
# Woodnut
# Zahn
# Abdeen
# Abraham
# Achecar
# Adams
# Adler
# Agnew
# Ahn
# Alexander
# Alexander
# Allan
# Almacari
# Amstutz
# Anderson
# Anderson
# Andreo
# Anseth
# Antebi
# Antoniades
# Anwar
# Aparicio
# Aribindi
# Askins
# Atkin
# Autry
# Avallone
# Axtmayer
# Ayres
# Backe
# Baker
# Baker
# Balint
# Ball
# Balsamo
# Barba
# Barber
# Bargren
# Barnett
# Baron
# Barrack
# Barrett
# Barrington
# Barsoum
# Bartholomew
# Bates
# Becker
# Behan
# Bender
# Bentley
# Berend
# Berkenblit
# Bernabe
# Bezwada
# Bhagia
# Bhalla
# Bharam
# Birdwell
# Biviji
# Blaha
# Blevins
# Bliss
# Block
# Blom
# Boettner
# Bolanos
# Bolhofner
# Bong
# Boone
# Borja
# Borowiecki
# Bortel
# Boucher
# Bowling
# Boyce
# Boyd
# Bradley
# Brandt
# Branovacki
# Briggs
# Brockmeyer
# Bronson
# Brooks
# Brooks
# Brown
# Buchalter
# Bugbee
# Burke
# Burke
# Burnett
# Burton
# Buscemi
# Butler
# Calendine
# Callander
# Cannova
# Carpenter
# Carter
# Carter
# Carvajal
# Cecil
# Champine
# Chan
# Chandran
# Chao
# Chhabra
# Chiang
# Chow
# Christie
# Cicoria
# Clark
# Clarke
# Clyburn
# Cochran
# Colizza
# Comadoll
# Comfort
# Companioni
# Congiusta
# Conlan
# Connors
# Cook
# Cook
# Cooney
# Cooperman
# Corces
# Gorczynski
# Courtney
# Cox
# Crofford
# Cromwell
# Cuellar
# Czajka
# Dabuzhsky
# Daley
# Dangles
# Davies
# Davis
# Dayton
# de Bari
# De Boer
# Della Valle
# Demers
# Denzin
# Deveney
# Diamond
# DiCaprio
# Di Cesare
# Diekmann
# DiFazio
# Diment
# Distler
# Doane
# Dobner
# Domb
# Downer
# Drinkwater
# Drucker
# Duda
# Duhon
# Dungy
# Dyeball
# Dzenis
# Earll
# Ebert
# Ebrahimpour
# Edwards
# Edwards
# Egan
# Eierle
# Ellis
# Ellis
# Elzaim
# Emerson
# Engh
# Enis
# Erens
# Etienne
# Evanich
# Fait
# Faust
# Feldman
# Ferguson
# Ferrante
# Ferro
# Fiewell
# Finch
# Fisher
# Fischer
# Fletcher
# Flynn Jr.
# Foglar
# Foster
# Fowble
# Fried
# Friedland
# Gajewski
# Gargaro
# Garver
# Gassner
# Geist
# Geller
# Gemas
# Gerber
# Ghazal
# Giordani
# Gilbert
# Gill
# Glaeser
# Gleason
# Glenn
# Glosser
# Gluek
# Goethe
# Gold
# Goldberg
# Goldsmith
# Goldstein
# Gorab
# Gorczynski
# Gordon
# Gordon
# Gordon
# Grady-Benson
# Graham
# Grandic
# Graybill
# Grecula
# Greenky
# Greenky
# Greene
# Gross
# Gross
# Gunther
# Gupta
# Gutowski
# Güzel
# Haidukewych
# Hajaliloo
# Hajj
# Hall
# Hallmann
# Hallstrom
# Halstead
# Hanmer
# Hansell
# Hansen
# Hartford
# Harwood
# Havel
# Hayek
# Hecht
# Heiner
# Heiser
# Heithoff
# Helgager
# Helmy
# Heming
# Henderson
# Henderson
# Hennessy
# Hepner
# Hickman
# Hicks
# Higginbotham III
# Hill
# Hilton
# Hirsch
# Hodrick
# Hoffman
# Holub
# Homan
# Homesley
# Hopkins
# Horner
# Hotchner
# Housman
# Howe
# Hozack
# Hribar
# Huang
# Hubers
# Hubley
# Huddleston
# Huddleston
# Huff
# Hung
# Hungerford
# Huo
# Hur
# Illgen
# Infante
# Jablonsky
# Jackson
# Jacobs
# Jaffe
# Jamali
# Jankiewicz
# Jaquith
# Jarrett
# Jennings
# Jerry
# Jibodh
# Jinnah
# Johnson
# Johnson
# Johnstone
# Kagan II
# Kalayjian
# Kane
# Karns
# Katz
# Kazdan
# Kazewych
# Keggi
# Keggi
# Kelley
# Kelly
# Kennedy
# Kennen
# Kennon
# Kepley
# Kessler
# Ketterer
# Khanuja
# Kim
# Kim
# Kim
# Kimball
# King
# Kirschenbaum
# Kitziger
# Klapper
# Klein
# Kleinhenz
# Klug
# Knight
# Knothe
# Knowlan
# Kohen
# Kolletis
# Komninakas
# Kopich
# Kress
# Kreuzer
# Kudrna
# Kuesis
# Kunec
# Kusuma
# Kwartowitz
# Lambe
# Lammens
# LaMont
# Landon
# Lang
# Lannin
# Larson
# Larson
# Lawrence
# Lazzarini
# Leland
# Lennen
# Lennon
# Levengood
# Levine
# Levine
# Lew
# Lewandowski
# Lieber
# Light
# Lilly
# Limbird
# Lindholm
# Liporace
# Litke
# Lombardi
# Lombardi
# Loniewski
# Lopez
# Lorei
# Louie
# Lowenberg
# Lunseth
# Luu
# Lyon
# Lyons
# Mabrey
# Macaulay
# Maddalon
# Magnus
# Maguire
# Mahoney
# Mai
# Maier
# Maitra
# Malchau
# Malin
# Malinick
# Manner
# Manning
# Marandola
# Marangi
# Marchand
# Mariorenzi
# Mark
# Markel
# Martin
# Martin
# Marwin
# Masini
# Mason
# Masonis
# Mathews
# Mathews
# Mathis
# Mathis
# Matta
# Matthews
# Matza
# Mayman
# Mayo
# McAllister
# McCarthy
# McKissick
# McClure
# McCoy
# McCulloch
# McGann
# McGrath
# McGuigan
# McKay
# McKissick
# McManaman
# McMaster
# McPherron
# Meehan
# Meere
# Meisles
# Melaragno
# Meldrum
# Melendez
# Mendelson
# Mendelson
# Mendelson
# Mendez
# Menendez
# Mensch
# Merkel
# Merkow
# Mesko
# Meyer
# Michalski
# Mikaelian
# Miller
# Miller
# Miller
# Miller
# Minotti
# Mirsky
# Mishra
# Mitchell
# Mitzelfelt
# Moe
# Mohler
# Mont
# Montijo (senior)
# Moore
# Morgan
# Mori
# Morrison
# Moutsatson
# Muench
# Muir
# Muller
# Murphy
# Myerthall
# Nagarkatti
# Naidoo
# Nallamothu
# Nasar
# Nasser
# Nayfeh
# Nelsen-Freund
# Nelson
# Nelson
# Nguyen
# Nunley
# Oakes
# O'Connor
# Oh
# O'Keefe
# Okun
# Olenyn
# Olson
# Omari
# O'Meara
# O'Neill
# Oppenheim
# Oskouei
# Ozolin
# Padgett
# Palmer
# Palmer
# Panek
# Parker
# Patel
# Paul
# Peatman
# Pelker
# Pellicci
# Penenberg
# Petty
# Philippon
# Phillips
# Pittman
# Pizzurro
# Pocze
# Polakoff
# Polifroni
# Poole
# Postma
# Powell
# Powell
# Pressman
# Price
# Pritchett
# Pugh
# Pullen
# Puri
# Quesada
# Ranawat
# Randall
# Rao
# Ratcliffe
# Raterman
# Rathjen
# Ray
# Ready
# Reardon
# Rector
# Redondo
# Reeves
# Reff
# Reilly
# Reiss
# Reitman
# Richman
# Riegler
# Ries
# Rifai
# Roberts
# Roberts
# Robinson II
# Rodin
# Rodricks
# Rodrigo
# Rodriguez
# Rodriguez
# Rogerson
# Romanelli
# Rosabal
# Rosen
# Rosen
# Ross
# Roye
# Rubin
# Rubins
# Rubinstein
# Russell
# Russinoff
# Ryan
# Saadi
# Saluja
# Sanders
# Saslow
# Schaefer
# Schiffman
# Schinsky
# Schmalzried
# Schmidt
# Schmitt
# Schneider
# Schneider
# Schreck
# Schubert
# Schultz
# Schultz
# Schultz
# Schultz
# Schutzer
# Schwartz
# Scobercea
# Scott
# Scott
# Seaquist
# Sellinger
# Serocki
# Sewell
# Seymour
# Shah
# Shanfield
# Shapiro
# Sharkey
# Sharma
# Sheehan
# Sheinkop
# Shekhman
# Sheldon
# Shell
# Sherfey
# Sheth
# Shinar
# Shrader
# Shrock
# Silverton
# Simenstad
# Simmons
# Simpson
# Sirounian
# Skinner
# Sladek
# Slover
# Smires
# Smith
# Smith
# Smith
# Smith
# Smucker
# Snider
# Snyder
# Sobeck
# Sparks
# Sparling
# Specht
# Sporer
# Springer
# Squire
# Stachniw
# Stamos
# Star
# Stein
# Steinfeld
# Stelmach
# Stephany
# Stephenson
# Stewart
# Stewart
# Stocks
# Stolarski
# Stroemer
# Stubbs
# Stuchin
# Stulberg
# Su
# Suprock
# Surdyka
# Swank
# Swanson
# Sydney
# Tai
# Talmo
# Tapadiya
# Teeny
# Telfer
# Terefenko
# Thomas
# Thomas
# Thometz
# Thompson
# Thompson
# Thorsett
# Tilzey
# Tomek
# Toulson
# Trousdale
# Tuttle
# Umlas
# Unger
# Ure
# Vail
# Valadie
# Valdivia
# van Dommelen
# Van Flandren
# Vella
# Verner
# Villafuerte
# Viola
# Volpe
# Vorlicky
# Vrabec
# Wagner
# Waldman
# Walkiewicz
# Wallskog
# Walsh
# Walter
# Ward
# Ward
# Wartinbee
# Watson
# Weeden
# Weisstein
# Wellborn
# Welborn
# Wertz
# Whatley
# Wiersema
# Williams
# Wills
# Wind
# Wolanin
# Wood
# Wood
# Wolff
# Workman
# Wright
# Wu
# Yap
# Yi
# Youm
# Yun
# Zambrano
# Zarin
# Zeidan
# Zelicof
# Zieger
# Zuckerman
# Crovetti Jr.
# Evans
# Young
# Yoo
# Pearson
# Skinner

# %%
df
# Out:
#      orthopedic_surgeon_first_name orthopedic_surgeon_surname  \
# 0                          Michael                   Anderson
# 1                             Neil                    Bergman
# 2                            Roger                   Brighton
# 3                         Roderick                     Brooks
# 4                        Rodney E.                    Dalziel
# ...                            ...                        ...
# 1031                    Jeffrey S.                      Zarin
# 1032                       Fady D.                     Zeidan
# 1033                     Steven B.                    Zelicof
# 1034                       Cory D.                     Zieger
# 1035                     Joseph D.                  Zuckerman
#
#                                              jpg_doctor      born_year  \
# 0                                         missing_value  missing_value
# 1                           X (doctors/neilbergman.jpg)  missing_value
# 2                         X (doctors/rogerbrighton.jpg)  missing_value
# 3                        X (doctors/roderickbrooks.jpg)  missing_value
# 4                            X (doctors/roddalziel.jpg)  missing_value
# ...                                                 ...            ...
# 1031                                      missing_value  missing_value
# 1032                                      missing_value  missing_value
# 1033  X (file:///C:\Users\Ron%20van%20Mierlo\AppData...  missing_value
# 1034  X (file:///C:\Users\Ron%20van%20Mierlo\AppData...  missing_value
# 1035  X (file:///C:\Users\Ron%20van%20Mierlo\AppData...  missing_value
#
#                                                 address                street  \
# 0                  Murdoch University Medical\n  Centre     100 Murdoch Drive
# 1                           Warringal Medical\n  Centre   214 Burgundy Street
# 2        Central West Orthopaedics\n  & Sports Injuries    30 Campbell Street
# 3                                         missing_value      2 Redleaf Avenue
# 4                           Melbourne Orthopaedic Group  33 The Avenue Street
# ...                                                 ...                   ...
# 1031                                      missing_value   720 Harrison Avenue
# 1032  Suncoast Orthopaedics\n  & Sports Medicine Center   10441 Quality Drive
# 1033                    Specialty Orthopaedics,\n  PLLC      311 North Street
# 1034                             Bone & Joint Institute  2611 Electric Avenue
# 1035                 NYU Hospital for Joint\n  Diseases  301 East 17th Street
#
#               local          city postal_code    country  ...  \
# 0          Suite 10       Murdoch         W-A  Australia  ...
# 1          Suite 10    Heidelberg    VIC 3084  Australia  ...
# 2         Suite 204     Blacktown    NSW 2148  Australia  ...
# 3     missing_value     Wahroonga    NSW 2076  Australia  ...
# 4           Windsor     Melbourne    VIC 3181  Australia  ...
# ...             ...           ...         ...        ...  ...
# 1031  missing_value        Boston    MA 02118        USA  ...
# 1032      Suite 202   Spring Hill    FL 34609        USA  ...
# 1033      Suite 206  White Plains    NY 10605        USA  ...
# 1034        Suite E    Port Huron    MI 48060        USA  ...
# 1035     Suite 1402      New York    NY 10003        USA  ...
#
#      this_joint_capsule_saved_all cut_muscles_is_fixed_again  \
# 0                   missing_value              missing_value
# 1                   missing_value              missing_value
# 2                   missing_value              missing_value
# 3                   missing_value              missing_value
# 4                   missing_value              missing_value
# ...                           ...                        ...
# 1031                missing_value              missing_value
# 1032                missing_value              missing_value
# 1033                missing_value              missing_value
# 1034                missing_value              missing_value
# 1035                missing_value              missing_value
#
#      complete_opera_report_is_given hr_average_size hr_average_location  \
# 0                     missing_value   missing_value       missing_value
# 1                     missing_value   missing_value       missing_value
# 2                     missing_value   missing_value       missing_value
# 3                     missing_value   missing_value       missing_value
# 4                     missing_value   missing_value       missing_value
# ...                             ...             ...                 ...
# 1031                  missing_value   missing_value       missing_value
# 1032                  missing_value   missing_value       missing_value
# 1033                  missing_value   missing_value       missing_value
# 1034                  missing_value   missing_value       missing_value
# 1035                  missing_value   missing_value       missing_value
#
#      assesses_x-ray x-ray_at_discharge two-sided_operation foreign_patients  \
# 0     missing_value      missing_value       missing_value    missing_value
# 1     missing_value      missing_value       missing_value    missing_value
# 2     missing_value      missing_value       missing_value    missing_value
# 3     missing_value      missing_value       missing_value    missing_value
# 4     missing_value      missing_value       missing_value    missing_value
# ...             ...                ...                 ...              ...
# 1031  missing_value      missing_value       missing_value    missing_value
# 1032  missing_value      missing_value       missing_value    missing_value
# 1033  missing_value      missing_value       missing_value    missing_value
# 1034  missing_value      missing_value       missing_value    missing_value
# 1035  missing_value      missing_value       missing_value    missing_value
#
#      patient-reported_complications
# 0                     missing_value
# 1                     missing_value
# 2                     missing_value
# 3                     missing_value
# 4                     missing_value
# ...                             ...
# 1031                  missing_value
# 1032                  missing_value
# 1033                  missing_value
# 1034                  missing_value
# 1035                  missing_value
#
# [1036 rows x 35 columns]

# %%
df.to_csv(data, index=False)

# %%
df = pd.read_csv(data, sep=',')

# %%
df.head()
# Out:
#   orthopedic_surgeon_first_name orthopedic_surgeon_surname  \
# 0                       Michael                   Anderson
# 1                          Neil                    Bergman
# 2                         Roger                   Brighton
# 3                      Roderick                     Brooks
# 4                     Rodney E.                    Dalziel
#
#                        jpg_doctor      born_year  \
# 0                   missing_value  missing_value
# 1     X (doctors/neilbergman.jpg)  missing_value
# 2   X (doctors/rogerbrighton.jpg)  missing_value
# 3  X (doctors/roderickbrooks.jpg)  missing_value
# 4      X (doctors/roddalziel.jpg)  missing_value
#
#                                           address                street  \
# 0            Murdoch University Medical\n  Centre     100 Murdoch Drive
# 1                     Warringal Medical\n  Centre   214 Burgundy Street
# 2  Central West Orthopaedics\n  & Sports Injuries    30 Campbell Street
# 3                                   missing_value      2 Redleaf Avenue
# 4                     Melbourne Orthopaedic Group  33 The Avenue Street
#
#            local        city postal_code    country  ...  \
# 0       Suite 10     Murdoch         W-A  Australia  ...
# 1       Suite 10  Heidelberg    VIC 3084  Australia  ...
# 2      Suite 204   Blacktown    NSW 2148  Australia  ...
# 3  missing_value   Wahroonga    NSW 2076  Australia  ...
# 4        Windsor   Melbourne    VIC 3181  Australia  ...
#
#   this_joint_capsule_saved_all cut_muscles_is_fixed_again  \
# 0                missing_value              missing_value
# 1                missing_value              missing_value
# 2                missing_value              missing_value
# 3                missing_value              missing_value
# 4                missing_value              missing_value
#
#   complete_opera_report_is_given hr_average_size hr_average_location  \
# 0                  missing_value   missing_value       missing_value
# 1                  missing_value   missing_value       missing_value
# 2                  missing_value   missing_value       missing_value
# 3                  missing_value   missing_value       missing_value
# 4                  missing_value   missing_value       missing_value
#
#   assesses_x-ray x-ray_at_discharge two-sided_operation foreign_patients  \
# 0  missing_value      missing_value       missing_value    missing_value
# 1  missing_value      missing_value       missing_value    missing_value
# 2  missing_value      missing_value       missing_value    missing_value
# 3  missing_value      missing_value       missing_value    missing_value
# 4  missing_value      missing_value       missing_value    missing_value
#
#   patient-reported_complications
# 0                  missing_value
# 1                  missing_value
# 2                  missing_value
# 3                  missing_value
# 4                  missing_value
#
# [5 rows x 35 columns]

# %%
import requests
from bs4 import BeautifulSoup

# URL of the web page to scrape
url = 'https://www.hipresurfacingsite.com/list-of-doctors.php'

# Send a GET request to the web page
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Find all <strong> tags on the page
    strong_tags = soup.find_all('strong')
    
    # Extract and store the names of doctors
    doctors = []
    for tag in strong_tags:
        name = tag.get_text(strip=True)
        # Append the name to the list if it seems to be a doctor's name
        # This can be customized if needed (e.g., by checking the length or format)
        if len(name.split()) >= 2:  # Assuming names are at least two words
            doctors.append(name)
    
    # Display the list of doctors
    for doctor in doctors:
        print(doctor)
else:
    print(f"Failed to retrieve the web page. Status code: {response.status_code}")
# Out:
# Scott Ball*, MD 200+
# Peter W. Callander, MD 1000+
# Dr. Thomas Ferro 250+
# Robert J. Gilbert, MD 300+
# Herbert D. Huddleston, MD 100+
# Joseph Jankiewicz, MD
# Thomas Parker Vail, MD 300+
# Cynthia M. Kelly, MD
# James B. Rector, MD 400+
# John Keggi, MD  220+
# Robert Edward "Ted" Kennon, MD
# Peter Brooks MD, FRCS(C) 4600 BHR
# Vincent A. Fowble, MD 300+
# Dr. Stephen Raterman, MD, FACS 875+
# Dr. Edward Stolarski
# Alan Valadie, MD
# Dr. Stephen Smith, MD 100+
# Collin Poole, MD 550+
# Craig J. Della Valle, MD   300+ BHR
# Dr. Scott Rubinstein
# Dr Eugene Lopez
# Dr. Scott M. Cook 320+
# Dr. Michael Jacobs, M.D. 100+
# Joseph C. Finch, D.O.* (email Vicky for email consults)  200+  BHR
# Dr. Philip Thomas Schmitt 570+
# Dr. David Palmer 500+
# Dr. Robert Trousdale
# Dr. Robert L. Barrack, M.D. 400+
# Dr. Michael Crovetti Jr.
# Dr. Edwin Su
# Dr. Friedrich Boettner*
# Dr. Michael Clarke 1500+
# Dr. William Macaulay 330+
# Scott E. Marwin, MD, FAAOS 1030+
# Dr. Michael A Mont
# Steven B. Zelicof, M.D. 175+
# Riyaz H. Jinnah, M.D. FRCS
# John L. Masonis, MD
# William G. Ward, MD
# Sharat K. Kusuma* MD, MBA 400 + BHR (Active)
# Dr. Stuart Gordon 40+ BHR
# Robert C. Marchand, MD 600+
# Dr. Thomas Gross* 6000+ Hip Resurfacings, 1300 Outpatient
# Dr. Andrew Shinar
# Dr. Theodore Crofford 250+
# John A. Evans, MD 120+
# Michael Grecula, M.D.
# Dr. Robert Schmidt 200+
# Richard Schubert, M.D
# Dr. Gregory Stocks 140+
# Dr. Stephen H. Weeden  BHR  800+
# Joshua M Hickman MD 400+
# Dr. C. Anderson Engh 100+
# James W. Pritchett, M.D. 3679+
# Edward Sparling, M.D. 300+
# John S. Rogerson*, MD 800+BHR
# Dr Stephen McMahon 1000+
# Mr Andrew Shimmin FRAC 1000+
# Michael Solomon
# Mr. David Young 800+
# A. Prof. Bill Walter 500+
# Dr. Koen De Smet* 5600
# Dr. Erwin Jansegers 850+ BHR and 50+ BMHR
# Dr. Lafayette Lage
# John Antoniou MD, PhD, FRCSC 800+
# Ethan Lichtblau, MD, FRCS(C)
# Emil Schemitsch, MD
# Paul Kim, MD 700+
# Dr. Frank Smith 300+
# Dr. Paul Beaulé 500+
# M. Christine Young *, MD FRCS(C)FRCS(A)
# James R. MacKenzie, M.D. FRCS(C)
# Dr. Jim Powell
# Dr. Jason Werle
# Dr. Chris Whately BSc, MD, FRCS (Canada) American Board Certified 200+
# Prof. Dr. med. Michael Faensen 2100+
# Priv. Doz. Dr. med. Ludger Gerdesmeyer 300+
# Dr. med. Raimund Voelker 500+ BHR, 150 BMHR
# Dr. Vijay C. Bose* 2000+
# Dr. Kaushal C. Malhan
# Paul Nicholson MCh., FRCS (Orth) 300+
# Dr. Daniel Levin M.D. 150+
# Dr. Myung Chul Yoo  1000+ Conserve Plus
# L. Paul A. Bom, MD, Ph 500+
# Dr. Hugh R.L. Blackley 150+
# Dr. Leith Stewart 300+
# Mr. Mark Bloomfield 1000+
# Mr. Hugh J Clarke MBBS, FRCS
# Professor Justin P Cobb MCh(Oxon) FRCS 500+
# Mr. M. Fordyce
# Mr. Jeremy Latham MA MCh FRCS(Orth) 700+
# Mr Andrew Manktelow 700+
# Mr. Derek McMinn FRCS 3600+
# Mr. J N O'Hara, FRCS, FRCSI MCh 1500+
# Mr. Andrew Pearson  800+
# Professor JB Richardson 400+
# Mr John Skinner 500+
# Mr. Ronan Treacy 5000+
# Below is a complete list of all hip surgeons that have been trained to do resurfacing.  Many no longer do the procedure but have been trained in it only, so please use the lists below with caution

# %%
with open('names.txt', 'r') as file:
    # Create an empty list to store the lines
    lines = []

    # Iterate over the lines of the file
    for line in file:
        # Remove the newline character at the end of the line
        line = line.strip().split()

        # Append the line to the list
        lines.append(line)
    print(lines)
# Out:
# [['Scott', 'Ball'], ['Peter', 'W.', 'Callander'], ['Dr.', 'Thomas', 'Ferro'], ['Robert', 'J.', 'Gilbert'], ['Herbert', 'D.', 'Huddleston'], ['Joseph', 'Jankiewicz'], ['Thomas', 'Parker', 'Vail'], ['Cynthia', 'M.', 'Kelly'], ['James', 'B.', 'Rector'], ['John', 'Keggi'], ['Robert', 'Edward', '"Ted"', 'Kennon'], ['Peter', 'Brooks'], ['Vincent', 'A.', 'Fowble'], ['Stephen', 'Raterman'], ['Edward', 'Stolarski'], ['Alan', 'Valadie'], ['Stephen', 'Smith'], ['Collin', 'Poole'], ['Craig', 'J.', 'Della', 'Valle'], ['Scott', 'Rubinstein'], ['Eugene', 'Lopez'], ['Scott', 'M.', 'Cook'], ['Michael', 'Jacobs'], ['Joseph', 'C.', 'Finch'], ['Philip', 'Thomas', 'Schmitt'], ['David', 'Palmer'], ['Robert', 'Trousdale'], ['Robert', 'L.', 'Barrack'], ['Michael', 'Crovetti', 'Jr.'], ['Edwin', 'Su'], ['Friedrich', 'Boettner'], ['Michael', 'Clarke'], ['William', 'Macaulay'], ['Michael', 'A', 'Mont'], ['Steven', 'B.', 'Zelicof'], ['Riyaz', 'H.', 'Jinnah'], ['John', 'L.', 'Masonis'], ['William', 'G.', 'Ward'], ['Sharat', 'K.', 'Kusuma'], ['Dr.', 'Stuart', 'Gordon'], ['Robert', 'C.', 'Marchand'], ['Thomas', 'Gross'], ['Dr.', 'Andrew', 'Shinar'], ['Dr.', 'Theodore', 'Crofford'], ['John', 'A.', 'Evans'], ['Michael', 'Grecula'], ['Dr.', 'Robert', 'Schmidt'], ['Richard', 'Schubert'], ['Gregory', 'Stocks'], ['Stephen', 'H.', 'Weeden'], ['Joshua', 'M', 'Hickman'], ['C.', 'Anderson'], ['James', 'W.', 'Pritchett'], ['Edward', 'Sparling'], ['John', 'S.', 'Rogerson'], ['Stephen', 'McMahon'], ['Andrew', 'Shimmin'], ['Michael', 'Solomon'], ['David', 'Young'], ['Koen', 'De', 'Smet'], ['Erwin', 'Jansegers'], ['Lafayette', 'Lage'], ['John', 'Antoniou'], ['Ethan', 'Lichtblau'], ['Emil', 'Schemitsch'], ['Paul', 'Kim'], ['Frank', 'Smith'], ['Paul', 'Beaulé'], ['M.', 'Christine', 'Young'], ['James', 'R.', 'MacKenzie'], ['Jim', 'Powell'], ['Jason', 'Werle'], ['Chris', 'Whately'], ['Michael', 'Faensen'], ['Ludger', 'Gerdesmeyer'], ['Raimund', 'Voelker'], ['Vijay', 'C.', 'Bose'], ['Kaushal', 'C.', 'Malhan'], ['Paul', 'Nicholson'], ['Dr.', 'Daniel', 'Levin'], ['Dr.', 'Myung', 'Chul', 'Yoo'], ['L.', 'Paul', 'A.', 'Bom'], ['Dr.', 'Hugh', 'R.L.', 'Blackley'], ['Dr.', 'Leith', 'Stewart'], ['Mr.', 'Mark', 'Bloomfield'], ['Mr.', 'Hugh', 'J', 'Clarke'], ['Professor', 'Justin', 'P', 'Cobb'], ['Mr.', 'M.', 'Fordyce'], ['Mr.', 'Jeremy', 'Latham'], ['Mr', 'Andrew', 'Manktelow'], ['Mr.', 'Derek', 'McMinn'], ['Mr.', 'J', 'N', "O'Hara"], ['Mr.', 'Andrew', 'Pearson'], ['Professor', 'JB', 'Richardson'], ['Mr', 'John', 'Skinner'], [], [], [], [], [], []]

# %%
print(df.columns.tolist())
# Out:
# ['orthopedic_surgeon_first_name', 'orthopedic_surgeon_surname', 'jpg_doctor', 'born_year', 'address', 'street', 'local', 'city', 'postal_code', 'country', 'phone_normal', 'phone_free_of_charge', 'fax', 'mobile', 'email', 'homepage', 'number_hr', 'adjusted', 'number_thr', 'number_bmhr', 'type_of_hr_prosthesis', 'type_of_thr_prosthesis', 'operational_technique', 'anesthetic', 'cement_femur_side', 'this_joint_capsule_saved_all', 'cut_muscles_is_fixed_again', 'complete_opera_report_is_given', 'hr_average_size', 'hr_average_location', 'assesses_x-ray', 'x-ray_at_discharge', 'two-sided_operation', 'foreign_patients', 'patient-reported_complications']

# %%
with open('names.txt', 'r') as file:
    lines = file.readlines()
    for line in lines: line = line.strip().split() 
    n = len(lines)
new_col = []
for index, row in df.iterrows():
    f = row['orthopedic_surgeon_first_name'].strip().split()[0]
    s = row['orthopedic_surgeon_surname'].strip()
   # print(s)
    #print(f)
    #print(row['Orthopedic surgeon first name'], row['Orthopedic surgeon surname'])
    for line in lines:
                
        if s in line:
           # print(s)
            if f in line:        
                new_col.append('Yes')
               # print(f, s, line)
                
                lines.remove(line)
                #lines.remove(r'\n')
                break
           # elif f not in line: print('*', f, s, line)
    if len(new_col) == index: new_col.append('No')
#print(new_col)
print(index, len(new_col))
print(new_col.count('Yes'), n)
print(lines)
#print(new_col)
# Out:
# 1031 1032
# 95 101
# ['\n', '\n', '\n', '\n', '\n', '\n']

# %%
df.columns
# Out:
# Index(['orthopedic_surgeon_first_name', 'orthopedic_surgeon_surname',
#        'jpg_doctor', 'born_year', 'address', 'street', 'local', 'city',
#        'postal_code', 'country', 'phone_normal', 'phone_free_of_charge', 'fax',
#        'mobile', 'email', 'homepage', 'number_hr', 'adjusted', 'number_thr',
#        'number_bmhr', 'type_of_hr_prosthesis', 'type_of_thr_prosthesis',
#        'operational_technique', 'anesthetic', 'cement_femur_side',
#        'this_joint_capsule_saved_all', 'cut_muscles_is_fixed_again',
#        'complete_opera_report_is_given', 'hr_average_size',
#        'hr_average_location', 'assesses_x-ray', 'x-ray_at_discharge',
#        'two-sided_operation', 'foreign_patients',
#        'patient-reported_positive_outcomes', 'patient-reported_complications'],
#       dtype='object')

# %%
df.insert(loc = 34,
          column = 'patient-reported_positive_outcomes',
          value=new_col)

# %%
check = df[(df['patient-reported_positive_outcomes'] == 'No')]
print(check['orthopedic_surgeon_surname'])
# Out:
# 0        Anderson
# 1         Bergman
# 2        Brighton
# 3          Brooks
# 4         Dalziel
#           ...
# 1020     Zambrano
# 1021        Zarin
# 1022       Zeidan
# 1024       Zieger
# 1025    Zuckerman
# Name: orthopedic_surgeon_surname, Length: 937, dtype: object

# %%
df
# Out:
#      orthopedic_surgeon_first_name orthopedic_surgeon_surname  \
# 0                          Michael                   Anderson
# 1                             Neil                    Bergman
# 2                            Roger                   Brighton
# 3                         Roderick                     Brooks
# 4                        Rodney E.                    Dalziel
# ...                            ...                        ...
# 1027                       John A.                      Evans
# 1028                  M. Christine                      Young
# 1029                    Myung Chul                        Yoo
# 1030                        Andrew                    Pearson
# 1031                          John                    Skinner
#
#                           jpg_doctor      born_year  \
# 0                      missing_value  missing_value
# 1        X (doctors/neilbergman.jpg)  missing_value
# 2      X (doctors/rogerbrighton.jpg)  missing_value
# 3     X (doctors/roderickbrooks.jpg)  missing_value
# 4         X (doctors/roddalziel.jpg)  missing_value
# ...                              ...            ...
# 1027                             NaN            NaN
# 1028                             NaN            NaN
# 1029                             NaN            NaN
# 1030                             NaN            NaN
# 1031                             NaN            NaN
#
#                                                 address  \
# 0                  Murdoch University Medical\n  Centre
# 1                           Warringal Medical\n  Centre
# 2        Central West Orthopaedics\n  & Sports Injuries
# 3                                         missing_value
# 4                           Melbourne Orthopaedic Group
# ...                                                 ...
# 1027                                                NaN
# 1028                                    Fracture Clinic
# 1029  Dept. of Orthopedic Surgery Kyung Hee Universi...
# 1030          Birmingham Hip Clinic BMI Priory Hospital
# 1031                Royal National Orthopaedic Hospital
#
#                         street          local           city  \
# 0            100 Murdoch Drive       Suite 10        Murdoch
# 1          214 Burgundy Street       Suite 10     Heidelberg
# 2           30 Campbell Street      Suite 204      Blacktown
# 3             2 Redleaf Avenue  missing_value      Wahroonga
# 4         33 The Avenue Street        Windsor      Melbourne
# ...                        ...            ...            ...
# 1027        414 Navarro Street     Suite 1128    San Antonio
# 1028    4040 Finch Avenue East      Suite 205    Scarborough
# 1029  Sangil-dong, Gangdong-gu           #149  Seoul 134-727
# 1030               Priory Road            NaN      Edgbaston
# 1031             Brockley Hill            NaN       Stanmore
#
#             postal_code            country  ... cut_muscles_is_fixed_again  \
# 0                   W-A          Australia  ...              missing_value
# 1              VIC 3084          Australia  ...              missing_value
# 2              NSW 2148          Australia  ...              missing_value
# 3              NSW 2076          Australia  ...              missing_value
# 4              VIC 3181          Australia  ...              missing_value
# ...                 ...                ...  ...                        ...
# 1027           TX 78205                USA  ...                        NaN
# 1028   Ontarion MIS 4V5     (416) 754-7312  ...                        NaN
# 1029              Korea  +82-2-440-7704, 9  ...                        NaN
# 1030  Birmingham B5 7UG     United Kingdom  ...                        NaN
# 1031  Middlesex HA7 4LP     United Kingdom  ...                        NaN
#
#      complete_opera_report_is_given hr_average_size hr_average_location  \
# 0                     missing_value   missing_value       missing_value
# 1                     missing_value   missing_value       missing_value
# 2                     missing_value   missing_value       missing_value
# 3                     missing_value   missing_value       missing_value
# 4                     missing_value   missing_value       missing_value
# ...                             ...             ...                 ...
# 1027                            NaN             NaN                 NaN
# 1028                            NaN             NaN                 NaN
# 1029                            NaN             NaN                 NaN
# 1030                            NaN             NaN                 NaN
# 1031                            NaN             NaN                 NaN
#
#      assesses_x-ray x-ray_at_discharge two-sided_operation foreign_patients  \
# 0     missing_value      missing_value       missing_value    missing_value
# 1     missing_value      missing_value       missing_value    missing_value
# 2     missing_value      missing_value       missing_value    missing_value
# 3     missing_value      missing_value       missing_value    missing_value
# 4     missing_value      missing_value       missing_value    missing_value
# ...             ...                ...                 ...              ...
# 1027            NaN                NaN                 NaN              NaN
# 1028            NaN                NaN                 NaN              NaN
# 1029            NaN                NaN                 NaN              NaN
# 1030            NaN                NaN                 NaN              NaN
# 1031            NaN                NaN                 NaN              NaN
#
#      patient-reported_positive_outcomes patient-reported_complications
# 0                                    No                  missing_value
# 1                                    No                  missing_value
# 2                                    No                  missing_value
# 3                                    No                  missing_value
# 4                                    No                  missing_value
# ...                                 ...                            ...
# 1027                                Yes                            NaN
# 1028                                Yes                  missing_value
# 1029                                Yes                  missing_value
# 1030                                Yes                            NaN
# 1031                                Yes                            NaN
#
# [1032 rows x 36 columns]

# %%
df.to_csv(data, index=False)

# %%
import pandas as pd
data = './Find-a-Doctor/data/hip_surgeons.csv'

# %%
df = pd.read_csv(data, sep=',')

# %%
df = df.drop('id', axis='columns')

# %%
df
# Out:
#      orthopedic_surgeon_first_name orthopedic_surgeon_surname  \
# 0                          Michael                   Anderson
# 1                             Neil                    Bergman
# 2                            Roger                   Brighton
# 3                         Roderick                     Brooks
# 4                        Rodney E.                    Dalziel
# ...                            ...                        ...
# 1027                       John A.                      Evans
# 1028                  M. Christine                      Young
# 1029                    Myung Chul                        Yoo
# 1030                        Andrew                    Pearson
# 1031                          John                    Skinner
#
#                           jpg_doctor      born_year  \
# 0                      missing_value  missing_value
# 1        X (doctors/neilbergman.jpg)  missing_value
# 2      X (doctors/rogerbrighton.jpg)  missing_value
# 3     X (doctors/roderickbrooks.jpg)  missing_value
# 4         X (doctors/roddalziel.jpg)  missing_value
# ...                              ...            ...
# 1027                   missing_value  missing_value
# 1028                   missing_value  missing_value
# 1029                   missing_value  missing_value
# 1030                   missing_value  missing_value
# 1031                   missing_value  missing_value
#
#                                                 address  \
# 0                  Murdoch University Medical\n  Centre
# 1                           Warringal Medical\n  Centre
# 2        Central West Orthopaedics\n  & Sports Injuries
# 3                                         missing_value
# 4                           Melbourne Orthopaedic Group
# ...                                                 ...
# 1027                                      missing_value
# 1028                                    Fracture Clinic
# 1029  Dept. of Orthopedic Surgery Kyung Hee Universi...
# 1030          Birmingham Hip Clinic BMI Priory Hospital
# 1031                Royal National Orthopaedic Hospital
#
#                         street          local           city  \
# 0            100 Murdoch Drive       Suite 10        Murdoch
# 1          214 Burgundy Street       Suite 10     Heidelberg
# 2           30 Campbell Street      Suite 204      Blacktown
# 3             2 Redleaf Avenue  missing_value      Wahroonga
# 4         33 The Avenue Street        Windsor      Melbourne
# ...                        ...            ...            ...
# 1027        414 Navarro Street     Suite 1128    San Antonio
# 1028    4040 Finch Avenue East      Suite 205    Scarborough
# 1029  Sangil-dong, Gangdong-gu           #149  Seoul 134-727
# 1030               Priory Road  missing_value      Edgbaston
# 1031             Brockley Hill  missing_value       Stanmore
#
#             postal_code            country  ... cut_muscles_is_fixed_again  \
# 0                   W-A          Australia  ...              missing_value
# 1              VIC 3084          Australia  ...              missing_value
# 2              NSW 2148          Australia  ...              missing_value
# 3              NSW 2076          Australia  ...              missing_value
# 4              VIC 3181          Australia  ...              missing_value
# ...                 ...                ...  ...                        ...
# 1027           TX 78205                USA  ...              missing_value
# 1028   Ontarion MIS 4V5     (416) 754-7312  ...              missing_value
# 1029              Korea  +82-2-440-7704, 9  ...              missing_value
# 1030  Birmingham B5 7UG     United Kingdom  ...              missing_value
# 1031  Middlesex HA7 4LP     United Kingdom  ...              missing_value
#
#      complete_opera_report_is_given hr_average_size hr_average_location  \
# 0                     missing_value   missing_value       missing_value
# 1                     missing_value   missing_value       missing_value
# 2                     missing_value   missing_value       missing_value
# 3                     missing_value   missing_value       missing_value
# 4                     missing_value   missing_value       missing_value
# ...                             ...             ...                 ...
# 1027                  missing_value   missing_value       missing_value
# 1028                  missing_value   missing_value       missing_value
# 1029                  missing_value   missing_value       missing_value
# 1030                  missing_value   missing_value       missing_value
# 1031                  missing_value   missing_value       missing_value
#
#      assesses_x-ray x-ray_at_discharge two-sided_operation foreign_patients  \
# 0     missing_value      missing_value       missing_value    missing_value
# 1     missing_value      missing_value       missing_value    missing_value
# 2     missing_value      missing_value       missing_value    missing_value
# 3     missing_value      missing_value       missing_value    missing_value
# 4     missing_value      missing_value       missing_value    missing_value
# ...             ...                ...                 ...              ...
# 1027  missing_value      missing_value       missing_value    missing_value
# 1028  missing_value      missing_value       missing_value    missing_value
# 1029  missing_value      missing_value       missing_value    missing_value
# 1030  missing_value      missing_value       missing_value    missing_value
# 1031  missing_value      missing_value       missing_value    missing_value
#
#      patient-reported_positive_outcomes patient-reported_complications
# 0                                    No                  missing_value
# 1                                    No                  missing_value
# 2                                    No                  missing_value
# 3                                    No                  missing_value
# 4                                    No                  missing_value
# ...                                 ...                            ...
# 1027                                Yes                  missing_value
# 1028                                Yes                  missing_value
# 1029                                Yes                  missing_value
# 1030                                Yes                  missing_value
# 1031                                Yes                  missing_value
#
# [1032 rows x 36 columns]

# %%
df.to_csv(data, index=False)

# %%
#df1 = df1.drop('id', axis='columns')
df1.insert(loc = 0,
          column = 'id',
          value=[str(i) for i in range(1032)])
df1
# Out:
#         id orthopedic_surgeon_first_name orthopedic_surgeon_surname  \
# 0        0                       Michael                   Anderson
# 1        1                          Neil                    Bergman
# 2        2                         Roger                   Brighton
# 3        3                      Roderick                     Brooks
# 4        4                     Rodney E.                    Dalziel
# ...    ...                           ...                        ...
# 1027  1027                       John A.                      Evans
# 1028  1028                  M. Christine                      Young
# 1029  1029                    Myung Chul                        Yoo
# 1030  1030                        Andrew                    Pearson
# 1031  1031                          John                    Skinner
#
#                           jpg_doctor      born_year  \
# 0                      missing_value  missing_value
# 1        X (doctors/neilbergman.jpg)  missing_value
# 2      X (doctors/rogerbrighton.jpg)  missing_value
# 3     X (doctors/roderickbrooks.jpg)  missing_value
# 4         X (doctors/roddalziel.jpg)  missing_value
# ...                              ...            ...
# 1027                   missing_value  missing_value
# 1028                   missing_value  missing_value
# 1029                   missing_value  missing_value
# 1030                   missing_value  missing_value
# 1031                   missing_value  missing_value
#
#                                                 address  \
# 0                  Murdoch University Medical\n  Centre
# 1                           Warringal Medical\n  Centre
# 2        Central West Orthopaedics\n  & Sports Injuries
# 3                                         missing_value
# 4                           Melbourne Orthopaedic Group
# ...                                                 ...
# 1027                                      missing_value
# 1028                                    Fracture Clinic
# 1029  Dept. of Orthopedic Surgery Kyung Hee Universi...
# 1030          Birmingham Hip Clinic BMI Priory Hospital
# 1031                Royal National Orthopaedic Hospital
#
#                         street          local           city  \
# 0            100 Murdoch Drive       Suite 10        Murdoch
# 1          214 Burgundy Street       Suite 10     Heidelberg
# 2           30 Campbell Street      Suite 204      Blacktown
# 3             2 Redleaf Avenue  missing_value      Wahroonga
# 4         33 The Avenue Street        Windsor      Melbourne
# ...                        ...            ...            ...
# 1027        414 Navarro Street     Suite 1128    San Antonio
# 1028    4040 Finch Avenue East      Suite 205    Scarborough
# 1029  Sangil-dong, Gangdong-gu           #149  Seoul 134-727
# 1030               Priory Road  missing_value      Edgbaston
# 1031             Brockley Hill  missing_value       Stanmore
#
#             postal_code  ... cut_muscles_is_fixed_again  \
# 0                   W-A  ...              missing_value
# 1              VIC 3084  ...              missing_value
# 2              NSW 2148  ...              missing_value
# 3              NSW 2076  ...              missing_value
# 4              VIC 3181  ...              missing_value
# ...                 ...  ...                        ...
# 1027           TX 78205  ...              missing_value
# 1028   Ontarion MIS 4V5  ...              missing_value
# 1029              Korea  ...              missing_value
# 1030  Birmingham B5 7UG  ...              missing_value
# 1031  Middlesex HA7 4LP  ...              missing_value
#
#      complete_opera_report_is_given hr_average_size hr_average_location  \
# 0                     missing_value   missing_value       missing_value
# 1                     missing_value   missing_value       missing_value
# 2                     missing_value   missing_value       missing_value
# 3                     missing_value   missing_value       missing_value
# 4                     missing_value   missing_value       missing_value
# ...                             ...             ...                 ...
# 1027                  missing_value   missing_value       missing_value
# 1028                  missing_value   missing_value       missing_value
# 1029                  missing_value   missing_value       missing_value
# 1030                  missing_value   missing_value       missing_value
# 1031                  missing_value   missing_value       missing_value
#
#      assesses_x-ray x-ray_at_discharge two-sided_operation foreign_patients  \
# 0     missing_value      missing_value       missing_value    missing_value
# 1     missing_value      missing_value       missing_value    missing_value
# 2     missing_value      missing_value       missing_value    missing_value
# 3     missing_value      missing_value       missing_value    missing_value
# 4     missing_value      missing_value       missing_value    missing_value
# ...             ...                ...                 ...              ...
# 1027  missing_value      missing_value       missing_value    missing_value
# 1028  missing_value      missing_value       missing_value    missing_value
# 1029  missing_value      missing_value       missing_value    missing_value
# 1030  missing_value      missing_value       missing_value    missing_value
# 1031  missing_value      missing_value       missing_value    missing_value
#
#      patient-reported_positive_outcomes patient-reported_complications
# 0                                    No                  missing_value
# 1                                    No                  missing_value
# 2                                    No                  missing_value
# 3                                    No                  missing_value
# 4                                    No                  missing_value
# ...                                 ...                            ...
# 1027                                Yes                  missing_value
# 1028                                Yes                  missing_value
# 1029                                Yes                  missing_value
# 1030                                Yes                  missing_value
# 1031                                Yes                  missing_value
#
# [1032 rows x 37 columns]

# %%
data_index = './Find-a-Doctor/data/hip_surgeons_index.csv'
df.to_csv(data, index=False)
