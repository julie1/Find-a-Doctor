# %%
import pandas as pd
import requests

# %%
from googletrans import Translator
translator = Translator()

# %%
# URL of the webpage with the HTML table
url = 'https://www.resurfacingscan.be/ortopedlistan/drutoml.htm'

# Fetch the content of the webpage
response = requests.get(url)

# %%
###correct code
import pandas as pd
import requests
#from googletrans import Translator
from bs4 import BeautifulSoup

# URL of the webpage with the HTML table
url = 'https://www.resurfacingscan.be/ortopedlistan/drutoml.htm'

# Correct column names from the file
correct_column_names = [
    "orthopedic_surgeon_first_name", "orthopedic_surgeon_surname", "jpg_doctor", "born_year", "address", "street",
    "local", "city", "postal_code", "country", "phone_normal", "phone_free_of_charge", "fax", "mobile",
    "email", "homepage", "number_hr", "adjusted", "number_thr", "number_bmhr",
    "type_of_hr_prosthesis", "type_of_thr_prosthesis", "operational_technique", "anesthetic", "cement_femur_side",
    "this_joint_capsule_saved_all", "cut_muscles_is_fixed_again", "complete_opera_report_is_given", "hr_average_size",
    "hr_average_location", "assesses_x-ray", "x-ray_at_discharge", "two-sided_operation", "foreign_patients",
    "patient-reported_complications"
]

# Fetch the content of the webpage
response = requests.get(url)

# Check for a successful response
if response.status_code == 200:
    # Parse the webpage content with BeautifulSoup
    soup = BeautifulSoup(response.content, 'html.parser')

    # Find the table
    table = soup.find('table')

    # Extract all rows from the table
    rows = table.find_all('tr')

    # Extract the data into a list of dictionaries
    data = []
    for row in rows:
        cols = row.find_all('td')
        row_data = []
        for col in cols:
            # If there is an <a> tag, extract the URL
            link = col.find('a')
            if link:
                url = link.get('href')
                text = link.text
                # Combine text and URL
                row_data.append(f"{text} ({url})")
            else:
                row_data.append(col.text.strip())
        data.append(row_data)

    # Create a DataFrame
    df = pd.DataFrame(data)

    # Remove the first 6 rows and start from the 7th row
    df = df.iloc[6:1042].reset_index(drop=True)

    # Apply the correct column names
    df.columns = correct_column_names

    # Save the DataFrame to a CSV file
    df.to_csv('table_with_correct_columns.csv', index=False)
    print("HTML table with correct column names successfully converted to CSV!")
    df.to_csv('./Find-a-Doctor/data/hip_surgeons.csv', index=False)
    # Read the CSV file to check its head
    df_loaded = pd.read_csv('table_with_correct_columns.csv')

    # Display all column names
    print("Column Names:")
    print(df_loaded.columns.tolist())

    # Set pandas options to display all columns
    pd.set_option('display.max_columns', None)  # Show all columns

    # Display the first few rows with all columns
    print(df_loaded.head())

    # Display DataFrame information
    df_loaded.info()

else:
    print("Failed to retrieve the webpage.")
# Out:
# HTML table with correct column names successfully converted to CSV!
# Column Names:
# ['orthopedic_surgeon_first_name', 'orthopedic_surgeon_surname', 'jpg_doctor', 'born_year', 'address', 'street', 'local', 'city', 'postal_code', 'country', 'phone_normal', 'phone_free_of_charge', 'fax', 'mobile', 'email', 'homepage', 'number_hr', 'adjusted', 'number_thr', 'number_bmhr', 'type_of_hr_prosthesis', 'type_of_thr_prosthesis', 'operational_technique', 'anesthetic', 'cement_femur_side', 'this_joint_capsule_saved_all', 'cut_muscles_is_fixed_again', 'complete_opera_report_is_given', 'hr_average_size', 'hr_average_location', 'assesses_x-ray', 'x-ray_at_discharge', 'two-sided_operation', 'foreign_patients', 'patient-reported_complications']
#   orthopedic_surgeon_first_name orthopedic_surgeon_surname  \
# 0                       Michael                   Anderson
# 1                          Neil                    Bergman
# 2                         Roger                   Brighton
# 3                      Roderick                     Brooks
# 4                     Rodney E.                    Dalziel
#
#                        jpg_doctor  born_year  \
# 0                             NaN        NaN
# 1     X (doctors/neilbergman.jpg)        NaN
# 2   X (doctors/rogerbrighton.jpg)        NaN
# 3  X (doctors/roderickbrooks.jpg)        NaN
# 4      X (doctors/roddalziel.jpg)        NaN
#
#                                           address                street  \
# 0            Murdoch University Medical\n  Centre     100 Murdoch Drive
# 1                     Warringal Medical\n  Centre   214 Burgundy Street
# 2  Central West Orthopaedics\n  & Sports Injuries    30 Campbell Street
# 3                                             NaN      2 Redleaf Avenue
# 4                     Melbourne Orthopaedic Group  33 The Avenue Street
#
#        local        city postal_code    country       phone_normal  \
# 0   Suite 10     Murdoch         W-A  Australia  +61-8-93-66-18-18
# 1   Suite 10  Heidelberg    VIC 3084  Australia  +61-3-94-57-51-00
# 2  Suite 204   Blacktown    NSW 2148  Australia  +61-2-96-79-70-88
# 3        NaN   Wahroonga    NSW 2076  Australia  +61-2-94-89-96-11
# 4    Windsor   Melbourne    VIC 3181  Australia  +61-3-98-19-41-90
#
#   phone_free_of_charge                fax mobile  \
# 0                  NaN                NaN    NaN
# 1                  NaN  +61-3-94-57-73-74    NaN
# 2                  NaN  +61-2-96-72-49-36    NaN
# 3                  NaN  +61-2-94-89-96-33    NaN
# 4                  NaN                NaN    NaN
#
#                               email                            homepage  \
# 0                               NaN                                 NaN
# 1                               NaN  www.neilbergman.com.au/myself.html
# 2  info@centralwestorthopaedics.com    www.centralwestorthopaedics.com/
# 3       orthodoc@roderickbrooks.com              www.roderickbrooks.com
# 4            info@roddalziel.com.au               www.roddalziel.com.au
#
#   number_hr adjusted number_thr number_bmhr type_of_hr_prosthesis  \
# 0       NaN      NaN        NaN         NaN                   NaN
# 1       NaN      NaN        NaN         NaN                   NaN
# 2       NaN      NaN        NaN         NaN                   BHR
# 3       NaN      NaN        NaN         NaN                   NaN
# 4       NaN      NaN        NaN         NaN                   BHR
#
#   type_of_thr_prosthesis operational_technique anesthetic cement_femur_side  \
# 0                    NaN                   NaN        NaN               NaN
# 1                    NaN                   NaN        NaN               NaN
# 2                    NaN                   NaN        NaN               NaN
# 3                    NaN                   NaN        NaN               NaN
# 4                    NaN                   NaN        NaN               NaN
#
#   this_joint_capsule_saved_all cut_muscles_is_fixed_again  \
# 0                          NaN                        NaN
# 1                          NaN                        NaN
# 2                          NaN                        NaN
# 3                          NaN                        NaN
# 4                          NaN                        NaN
#
#   complete_opera_report_is_given hr_average_size hr_average_location  \
# 0                            NaN             NaN                 NaN
# 1                            NaN             NaN                 NaN
# 2                            NaN             NaN                 NaN
# 3                            NaN             NaN                 NaN
# 4                            NaN             NaN                 NaN
#
#   assesses_x-ray x-ray_at_discharge two-sided_operation foreign_patients  \
# 0            NaN                NaN                 NaN              NaN
# 1            NaN                NaN                 NaN              NaN
# 2            NaN                NaN                 NaN              NaN
# 3            NaN                NaN                 NaN              NaN
# 4            NaN                NaN                 NaN              NaN
#
#   patient-reported_complications
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1036 entries, 0 to 1035
# Data columns (total 35 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   orthopedic_surgeon_first_name   1023 non-null   object
#  1   orthopedic_surgeon_surname      1034 non-null   object
#  2   jpg_doctor                      579 non-null    object
#  3   born_year                       22 non-null     float64
#  4   address                         937 non-null    object
#  5   street                          935 non-null    object
#  6   local                           519 non-null    object
#  7   city                            1012 non-null   object
#  8   postal_code                     953 non-null    object
#  9   country                         1034 non-null   object
#  10  phone_normal                    950 non-null    object
#  11  phone_free_of_charge            42 non-null     object
#  12  fax                             406 non-null    object
#  13  mobile                          14 non-null     object
#  14  email                           321 non-null    object
#  15  homepage                        701 non-null    object
#  16  number_hr                       201 non-null    object
#  17  adjusted                        126 non-null    object
#  18  number_thr                      22 non-null     object
#  19  number_bmhr                     10 non-null     object
#  20  type_of_hr_prosthesis           921 non-null    object
#  21  type_of_thr_prosthesis          18 non-null     object
#  22  operational_technique           15 non-null     object
#  23  anesthetic                      16 non-null     object
#  24  cement_femur_side               22 non-null     object
#  25  this_joint_capsule_saved_all    7 non-null      object
#  26  cut_muscles_is_fixed_again      8 non-null      object
#  27  complete_opera_report_is_given  9 non-null      object
#  28  hr_average_size                 21 non-null     object
#  29  hr_average_location             52 non-null     object
#  30  assesses_x-ray                  31 non-null     object
#  31  x-ray_at_discharge              14 non-null     object
#  32  two-sided_operation             24 non-null     object
#  33  foreign_patients                28 non-null     object
#  34  patient-reported_complications  27 non-null     object
# dtypes: float64(1), object(34)
# memory usage: 283.4+ KB

# %%
df
# Out:
#      orthopedic_surgeon_first_name orthopedic_surgeon_surname  \
# 0                          Michael                   Anderson
# 1                             Neil                    Bergman
# 2                            Roger                   Brighton
# 3                         Roderick                     Brooks
# 4                        Rodney E.                    Dalziel
# ...                            ...                        ...
# 1031                    Jeffrey S.                      Zarin
# 1032                       Fady D.                     Zeidan
# 1033                     Steven B.                    Zelicof
# 1034                       Cory D.                     Zieger
# 1035                     Joseph D.                  Zuckerman
#
#                                              jpg_doctor born_year  \
# 0
# 1                           X (doctors/neilbergman.jpg)
# 2                         X (doctors/rogerbrighton.jpg)
# 3                        X (doctors/roderickbrooks.jpg)
# 4                            X (doctors/roddalziel.jpg)
# ...                                                 ...       ...
# 1031
# 1032
# 1033  X (file:///C:\Users\Ron%20van%20Mierlo\AppData...
# 1034  X (file:///C:\Users\Ron%20van%20Mierlo\AppData...
# 1035  X (file:///C:\Users\Ron%20van%20Mierlo\AppData...
#
#                                                 address                street  \
# 0                  Murdoch University Medical\n  Centre     100 Murdoch Drive
# 1                           Warringal Medical\n  Centre   214 Burgundy Street
# 2        Central West Orthopaedics\n  & Sports Injuries    30 Campbell Street
# 3                                                            2 Redleaf Avenue
# 4                           Melbourne Orthopaedic Group  33 The Avenue Street
# ...                                                 ...                   ...
# 1031                                                      720 Harrison Avenue
# 1032  Suncoast Orthopaedics\n  & Sports Medicine Center   10441 Quality Drive
# 1033                    Specialty Orthopaedics,\n  PLLC      311 North Street
# 1034                             Bone & Joint Institute  2611 Electric Avenue
# 1035                 NYU Hospital for Joint\n  Diseases  301 East 17th Street
#
#            local          city postal_code    country       phone_normal  \
# 0       Suite 10       Murdoch         W-A  Australia  +61-8-93-66-18-18
# 1       Suite 10    Heidelberg    VIC 3084  Australia  +61-3-94-57-51-00
# 2      Suite 204     Blacktown    NSW 2148  Australia  +61-2-96-79-70-88
# 3                    Wahroonga    NSW 2076  Australia  +61-2-94-89-96-11
# 4        Windsor     Melbourne    VIC 3181  Australia  +61-3-98-19-41-90
# ...          ...           ...         ...        ...                ...
# 1031                    Boston    MA 02118        USA  +1-61-76-38-56-33
# 1032   Suite 202   Spring Hill    FL 34609        USA  +1-35-26-86-61-14
# 1033   Suite 206  White Plains    NY 10605        USA  +1-91-46-86-01-11
# 1034     Suite E    Port Huron    MI 48060        USA  +1-81-09-87-98-71
# 1035  Suite 1402      New York    NY 10003        USA  +1-21-25-98-67-93
#
#      phone_free_of_charge                fax mobile  \
# 0
# 1                          +61-3-94-57-73-74
# 2                          +61-2-96-72-49-36
# 3                          +61-2-94-89-96-33
# 4
# ...                   ...                ...    ...
# 1031
# 1032                       +1-35-26-86-07-96
# 1033                       +1-91-46-86-89-64
# 1034
# 1035
#
#                                  email  \
# 0
# 1
# 2     info@centralwestorthopaedics.com
# 3          orthodoc@roderickbrooks.com
# 4               info@roddalziel.com.au
# ...                                ...
# 1031
# 1032
# 1033
# 1034
# 1035
#
#                                       homepage number_hr  adjusted number_thr  \
# 0
# 1           www.neilbergman.com.au/myself.html
# 2             www.centralwestorthopaedics.com/
# 3                       www.roderickbrooks.com
# 4                        www.roddalziel.com.au
# ...                                        ...       ...       ...        ...
# 1031
# 1032
# 1033      www.zelicofmd.com/pages/practice.php       175  May 2009
# 1034  http://bonejointinstitute.net/index.html
# 1035
#
#      number_bmhr type_of_hr_prosthesis type_of_thr_prosthesis  \
# 0
# 1
# 2                                  BHR
# 3
# 4                                  BHR
# ...          ...                   ...                    ...
# 1031                               BHR
# 1032                               BHR
# 1033                               BHR
# 1034                               BHR
# 1035                               BHR
#
#      operational_technique anesthetic cement_femur_side  \
# 0
# 1
# 2
# 3
# 4
# ...                    ...        ...               ...
# 1031
# 1032
# 1033
# 1034
# 1035
#
#      this_joint_capsule_saved_all cut_muscles_is_fixed_again  \
# 0
# 1
# 2
# 3
# 4
# ...                           ...                        ...
# 1031
# 1032
# 1033
# 1034
# 1035
#
#      complete_opera_report_is_given hr_average_size hr_average_location  \
# 0
# 1
# 2
# 3
# 4
# ...                             ...             ...                 ...
# 1031
# 1032
# 1033
# 1034
# 1035
#
#      assesses_x-ray x-ray_at_discharge two-sided_operation foreign_patients  \
# 0
# 1
# 2
# 3
# 4
# ...             ...                ...                 ...              ...
# 1031
# 1032
# 1033
# 1034
# 1035
#
#      patient-reported_complications
# 0
# 1
# 2
# 3
# 4
# ...                             ...
# 1031
# 1032
# 1033
# 1034
# 1035
#
# [1036 rows x 35 columns]
